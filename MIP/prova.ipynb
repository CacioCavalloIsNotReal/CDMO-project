# %%
# %run model.py "../instances/inst08.dat" "solutions/solution08"
# Out:
# Loading instance: ../instances/inst08.dat
# Instance Parameters Loaded:
#   Couriers (m): 8
#   Items (n): 10
# Solving MCP MIP with PuLP (Solver: PULP_CBC_CMD)...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/homebrew/Caskroom/miniconda/base/envs/environment/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/36/h9ntx1qx07ncdrcnhkyd0cd40000gn/T/c005974d0cfd4586933464fb9995f59c-pulp.mps -sec 300 -timeMode elapsed -branch -printingOptions all -solution /var/folders/36/h9ntx1qx07ncdrcnhkyd0cd40000gn/T/c005974d0cfd4586933464fb9995f59c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1015 COLUMNS
# At line 8649 RHS
# At line 9660 BOUNDS
# At line 10869 ENDATA
# Problem MODEL has 1010 rows, 1129 columns and 5376 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 300
# Option for timeMode changed from cpu to elapsed
# ...

# %%
# %run model_symbreak.py "../instances/inst01.dat" "solutions_symbreak/solution01" --nosym --solver "GUROBI_CMD"
# Out:
# usage: model_symbreak.py [-h] [--nosym] [--timelimit TIMELIMIT]
#                          [--approach_name APPROACH_NAME]
#                          [--solver {PULP_CBC_CMD,GUROBI_CMD}]
#                          instance_filepath output_json_filepath
# model_symbreak.py: error: argument --solver: expected one argument
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# %run solution_checker.py "MIP/solutions_symbreak" "check"
# Out:
# Check terminated.
# No errors detected!

# %%
import pulp as pl

pl.listSolvers()
# Out:
# ['GLPK_CMD',
#  'PYGLPK',
#  'CPLEX_CMD',
#  'CPLEX_PY',
#  'GUROBI',
#  'GUROBI_CMD',
#  'MOSEK',
#  'XPRESS',
#  'XPRESS',
#  'XPRESS_PY',
#  'PULP_CBC_CMD',
#  'COIN_CMD',
#  'COINMP_DLL',
#  'CHOCO_CMD',
#  'MIPCL_CMD',
#  'SCIP_CMD',
#  'FSCIP_CMD',
#  'SCIP_PY',
#  'HiGHS',
#  'HiGHS_CMD',
#  'COPT',
#  'COPT_DLL',
#  'COPT_CMD']
